# %%
import pandas as pd

# %%
import numpy as np

# %%
from plotly import __version__

# %%
print(__version__)
#version has to be higher than 1.12
# Out:
# 3.10.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
#This will allow to connect JavaScript to our notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
#This will allow us to use cufflinks offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Data

df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -0.797518 -1.806839 -1.620385  0.473644
# 1  1.956459  1.778799  0.696012 -0.574849
# 2  0.016206  1.422759 -0.434727  0.358539
# 3  0.202494 -2.274292  2.276664  1.754842
# 4 -1.584892 -0.439945  1.209580  1.233187

# %%
df2 = pd.DataFrame({'category':['A','B','C'], 'values':[32, 43, 50]})

# %%
df2
# Out:
#   category  values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()

# %%
# %matplotlib inline

# %%
df.plot()

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="ef6a155e-b4c7-4311-817d-a38722ffaca2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ef6a155e-b4c7-4311-817d-a38722ffaca2")) {
#                     Plotly.newPlot(
#                         'ef6a155e-b4c7-4311-817d-a38722ffaca2',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B' )
# Out:
# <div>
#
#
#             <div id="a808daff-5986-4428-a312-eec80a31f7c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a808daff-5986-4428-a312-eec80a31f7c0")) {
#                     Plotly.newPlot(
#                         'a808daff-5986-4428-a312-eec80a31f7c0',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers' )
# Out:
# <div>
#
#
#             <div id="18b933f3-9a92-47fa-9575-c01b41a495de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("18b933f3-9a92-47fa-9575-c01b41a495de")) {
#                     Plotly.newPlot(
#                         '18b933f3-9a92-47fa-9575-c01b41a495de',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers', size = 20 )
# Out:
# <div>
#
#
#             <div id="ed80872c-54b2-46ae-8392-acc3a9f1f942" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ed80872c-54b2-46ae-8392-acc3a9f1f942")) {
#                     Plotly.newPlot(
#                         'ed80872c-54b2-46ae-8392-acc3a9f1f942',
# ...

# %%
df2.iplot(kind='bar',x='category',y='values')
# Out:
# <div>
#
#
#             <div id="05a11098-00cc-4213-87ea-c7ed9f456598" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("05a11098-00cc-4213-87ea-c7ed9f456598")) {
#                     Plotly.newPlot(
#                         '05a11098-00cc-4213-87ea-c7ed9f456598',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "values", "orientation": "v", "text": "", "type": "bar", "uid": "7d310ecc-cdf0-4047-8331-7be569631498", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="83f776ec-eb95-4230-b0e7-9b7e1ca29c3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("83f776ec-eb95-4230-b0e7-9b7e1ca29c3b")) {
#                     Plotly.newPlot(
#                         '83f776ec-eb95-4230-b0e7-9b7e1ca29c3b',
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="62af2af1-9b44-47e1-a518-56360477d1d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("62af2af1-9b44-47e1-a518-56360477d1d8")) {
#                     Plotly.newPlot(
#                         '62af2af1-9b44-47e1-a518-56360477d1d8',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "f4a7d7f0-ced5-49a8-94a1-bb37f2f8ac5b", "x": ["A", "B", "C", "D"], "y": [100, 100, 100, 100]}],
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="c48bde69-c2e8-4e2c-9410-c64be5726d45" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c48bde69-c2e8-4e2c-9410-c64be5726d45")) {
#                     Plotly.newPlot(
#                         'c48bde69-c2e8-4e2c-9410-c64be5726d45',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "60473ab7-eddc-4559-b887-7d95e24e25c3", "x": ["A", "B", "C", "D"], "y": [-11.279194655823039, 11.42346308041669, 11.152958740187957, 1.8582766640502304]}],
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="035e4c10-b442-470e-b665-e07cd259a0bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("035e4c10-b442-470e-b665-e07cd259a0bf")) {
#                     Plotly.newPlot(
#                         '035e4c10-b442-470e-b665-e07cd259a0bf',
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[10,20,30,40,50], 'z':[500,400,300,200,100]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  40  200
# 4  5  50  100

# %%
df3.iplot(kind='surface')
# Out:
# <div>
#
#
#             <div id="b08f31fe-a043-4375-8529-ce322575120b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b08f31fe-a043-4375-8529-ce322575120b")) {
#                     Plotly.newPlot(
#                         'b08f31fe-a043-4375-8529-ce322575120b',
# ...

# %%
df31 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[10,20,30,40,50], 'z':[5,4,3,2,1]})

# %%
df31.iplot(kind='surface')
# Out:
# <div>
#
#
#             <div id="c559f126-6d9f-4350-b599-191547f1222c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c559f126-6d9f-4350-b599-191547f1222c")) {
#                     Plotly.newPlot(
#                         'c559f126-6d9f-4350-b599-191547f1222c',
# ...

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="5457d176-f8b4-43ae-a38e-6d276dfdb7ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5457d176-f8b4-43ae-a38e-6d276dfdb7ff")) {
#                     Plotly.newPlot(
#                         '5457d176-f8b4-43ae-a38e-6d276dfdb7ff',
# ...

# %%
df['A'].iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="b0825e41-91a9-43e6-a740-d0e61177a044" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b0825e41-91a9-43e6-a740-d0e61177a044")) {
#                     Plotly.newPlot(
#                         'b0825e41-91a9-43e6-a740-d0e61177a044',
# ...

# %%
df['A'].iplot(kind='hist', bins=30)
# Out:
# <div>
#
#
#             <div id="81aeed94-7b52-4f2d-8d91-f336ca318535" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("81aeed94-7b52-4f2d-8d91-f336ca318535")) {
#                     Plotly.newPlot(
#                         '81aeed94-7b52-4f2d-8d91-f336ca318535',
# ...

# %%
df.iplot(kind='hist', bins=30)
# Out:
# <div>
#
#
#             <div id="8cbd271d-14dc-4ef4-a283-25f59ecb1329" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8cbd271d-14dc-4ef4-a283-25f59ecb1329")) {
#                     Plotly.newPlot(
#                         '8cbd271d-14dc-4ef4-a283-25f59ecb1329',
# ...

# %%
#For stock data
df[['A','B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="f18aa4e0-ed3f-447e-a46f-ffe4dcdb041f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f18aa4e0-ed3f-447e-a46f-ffe4dcdb041f")) {
#                     Plotly.newPlot(
#                         'f18aa4e0-ed3f-447e-a46f-ffe4dcdb041f',
# ...

# %%
df.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>
#
#
#             <div id="5d14f80a-f7f3-4ebf-8423-6e321b783a90" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5d14f80a-f7f3-4ebf-8423-6e321b783a90")) {
#                     Plotly.newPlot(
#                         '5d14f80a-f7f3-4ebf-8423-6e321b783a90',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="214642c9-2446-45fa-985f-e5ef8e39b7c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("214642c9-2446-45fa-985f-e5ef8e39b7c6")) {
#                     Plotly.newPlot(
#                         '214642c9-2446-45fa-985f-e5ef8e39b7c6',
# ...

# %% [markdown]
# [For more information and reference on cufflinks please visit](hhtps://github.com/santosjorge/cufflinks)

# %%
hhtps://github.com/santosjorge/cufflinks
